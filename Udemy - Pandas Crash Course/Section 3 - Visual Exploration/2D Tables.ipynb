# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.normal(size=(6,6)), columns=[x for x in 'ABCDEF'])
df
# Out:
#           A         B         C         D         E         F
# 0 -0.183639  0.474137 -0.329255 -0.221098  1.544897  0.818156
# 1 -0.407643 -1.097898  0.991999 -1.151307  0.459036 -1.911524
# 2 -0.472914  0.840233 -0.133451  0.350722  1.618007 -0.882411
# 3 -0.095701 -1.092493 -0.008957  0.585711 -0.104442  1.083658
# 4  0.212805  2.210187  0.448831  0.403888  1.375825 -0.643548
# 5 -0.218494 -1.161965  0.484571  1.000136  0.627714  0.083205

# %%
def neg_red(x):
    return f"color: {'red' if x < 0 else 'white'}"
df.style.applymap(neg_red)
# Out:
# <style type="text/css">
# #T_e9e1e_row0_col0, #T_e9e1e_row0_col2, #T_e9e1e_row0_col3, #T_e9e1e_row1_col0, #T_e9e1e_row1_col1, #T_e9e1e_row1_col3, #T_e9e1e_row1_col5, #T_e9e1e_row2_col0, #T_e9e1e_row2_col2, #T_e9e1e_row2_col5, #T_e9e1e_row3_col0, #T_e9e1e_row3_col1, #T_e9e1e_row3_col2, #T_e9e1e_row3_col4, #T_e9e1e_row4_col5, #T_e9e1e_row5_col0, #T_e9e1e_row5_col1 {
#   color: red;
# }
# #T_e9e1e_row0_col1, #T_e9e1e_row0_col4, #T_e9e1e_row0_col5, #T_e9e1e_row1_col2, #T_e9e1e_row1_col4, #T_e9e1e_row2_col1, #T_e9e1e_row2_col3, #T_e9e1e_row2_col4, #T_e9e1e_row3_col3, #T_e9e1e_row3_col5, #T_e9e1e_row4_col0, #T_e9e1e_row4_col1, #T_e9e1e_row4_col2, #T_e9e1e_row4_col3, #T_e9e1e_row4_col4, #T_e9e1e_row5_col2, #T_e9e1e_row5_col3, #T_e9e1e_row5_col4, #T_e9e1e_row5_col5 {
#   color: white;
# }
# </style>
# <table id="T_e9e1e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9e1e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9e1e_row0_col0" class="data row0 col0" >-0.183639</td>
#       <td id="T_e9e1e_row0_col1" class="data row0 col1" >0.474137</td>
#       <td id="T_e9e1e_row0_col2" class="data row0 col2" >-0.329255</td>
#       <td id="T_e9e1e_row0_col3" class="data row0 col3" >-0.221098</td>
#       <td id="T_e9e1e_row0_col4" class="data row0 col4" >1.544897</td>
#       <td id="T_e9e1e_row0_col5" class="data row0 col5" >0.818156</td>
#     </tr>
#     <tr>
#       <th id="T_e9e1e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e9e1e_row1_col0" class="data row1 col0" >-0.407643</td>
#       <td id="T_e9e1e_row1_col1" class="data row1 col1" >-1.097898</td>
#       <td id="T_e9e1e_row1_col2" class="data row1 col2" >0.991999</td>
#       <td id="T_e9e1e_row1_col3" class="data row1 col3" >-1.151307</td>
#       <td id="T_e9e1e_row1_col4" class="data row1 col4" >0.459036</td>
#       <td id="T_e9e1e_row1_col5" class="data row1 col5" >-1.911524</td>
#     </tr>
#     <tr>
#       <th id="T_e9e1e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e9e1e_row2_col0" class="data row2 col0" >-0.472914</td>
#       <td id="T_e9e1e_row2_col1" class="data row2 col1" >0.840233</td>
#       <td id="T_e9e1e_row2_col2" class="data row2 col2" >-0.133451</td>
#       <td id="T_e9e1e_row2_col3" class="data row2 col3" >0.350722</td>
#       <td id="T_e9e1e_row2_col4" class="data row2 col4" >1.618007</td>
#       <td id="T_e9e1e_row2_col5" class="data row2 col5" >-0.882411</td>
#     </tr>
#     <tr>
#       <th id="T_e9e1e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e9e1e_row3_col0" class="data row3 col0" >-0.095701</td>
#       <td id="T_e9e1e_row3_col1" class="data row3 col1" >-1.092493</td>
#       <td id="T_e9e1e_row3_col2" class="data row3 col2" >-0.008957</td>
#       <td id="T_e9e1e_row3_col3" class="data row3 col3" >0.585711</td>
#       <td id="T_e9e1e_row3_col4" class="data row3 col4" >-0.104442</td>
#       <td id="T_e9e1e_row3_col5" class="data row3 col5" >1.083658</td>
#     </tr>
#     <tr>
#       <th id="T_e9e1e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e9e1e_row4_col0" class="data row4 col0" >0.212805</td>
#       <td id="T_e9e1e_row4_col1" class="data row4 col1" >2.210187</td>
#       <td id="T_e9e1e_row4_col2" class="data row4 col2" >0.448831</td>
#       <td id="T_e9e1e_row4_col3" class="data row4 col3" >0.403888</td>
#       <td id="T_e9e1e_row4_col4" class="data row4 col4" >1.375825</td>
#       <td id="T_e9e1e_row4_col5" class="data row4 col5" >-0.643548</td>
#     </tr>
#     <tr>
#       <th id="T_e9e1e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e9e1e_row5_col0" class="data row5 col0" >-0.218494</td>
#       <td id="T_e9e1e_row5_col1" class="data row5 col1" >-1.161965</td>
#       <td id="T_e9e1e_row5_col2" class="data row5 col2" >0.484571</td>
#       <td id="T_e9e1e_row5_col3" class="data row5 col3" >1.000136</td>
#       <td id="T_e9e1e_row5_col4" class="data row5 col4" >0.627714</td>
#       <td id="T_e9e1e_row5_col5" class="data row5 col5" >0.083205</td>
#     </tr>
#   </tbody>
# </table>

# %%
def gold_max(xs):
    m = xs.to_numpy().max()
    color = {True: "background-color: #c78f2e", False: ""}
    is_max = (xs == m).replace(color)
    return is_max
df.style.apply(gold_max, axis=None)
# Out:
# <style type="text/css">
# #T_f96e1_row4_col1 {
#   background-color: #c78f2e;
# }
# </style>
# <table id="T_f96e1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f96e1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f96e1_row0_col0" class="data row0 col0" >-0.183639</td>
#       <td id="T_f96e1_row0_col1" class="data row0 col1" >0.474137</td>
#       <td id="T_f96e1_row0_col2" class="data row0 col2" >-0.329255</td>
#       <td id="T_f96e1_row0_col3" class="data row0 col3" >-0.221098</td>
#       <td id="T_f96e1_row0_col4" class="data row0 col4" >1.544897</td>
#       <td id="T_f96e1_row0_col5" class="data row0 col5" >0.818156</td>
#     </tr>
#     <tr>
#       <th id="T_f96e1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f96e1_row1_col0" class="data row1 col0" >-0.407643</td>
#       <td id="T_f96e1_row1_col1" class="data row1 col1" >-1.097898</td>
#       <td id="T_f96e1_row1_col2" class="data row1 col2" >0.991999</td>
#       <td id="T_f96e1_row1_col3" class="data row1 col3" >-1.151307</td>
#       <td id="T_f96e1_row1_col4" class="data row1 col4" >0.459036</td>
#       <td id="T_f96e1_row1_col5" class="data row1 col5" >-1.911524</td>
#     </tr>
#     <tr>
#       <th id="T_f96e1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f96e1_row2_col0" class="data row2 col0" >-0.472914</td>
#       <td id="T_f96e1_row2_col1" class="data row2 col1" >0.840233</td>
#       <td id="T_f96e1_row2_col2" class="data row2 col2" >-0.133451</td>
#       <td id="T_f96e1_row2_col3" class="data row2 col3" >0.350722</td>
#       <td id="T_f96e1_row2_col4" class="data row2 col4" >1.618007</td>
#       <td id="T_f96e1_row2_col5" class="data row2 col5" >-0.882411</td>
#     </tr>
#     <tr>
#       <th id="T_f96e1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f96e1_row3_col0" class="data row3 col0" >-0.095701</td>
#       <td id="T_f96e1_row3_col1" class="data row3 col1" >-1.092493</td>
#       <td id="T_f96e1_row3_col2" class="data row3 col2" >-0.008957</td>
#       <td id="T_f96e1_row3_col3" class="data row3 col3" >0.585711</td>
#       <td id="T_f96e1_row3_col4" class="data row3 col4" >-0.104442</td>
#       <td id="T_f96e1_row3_col5" class="data row3 col5" >1.083658</td>
#     </tr>
#     <tr>
#       <th id="T_f96e1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f96e1_row4_col0" class="data row4 col0" >0.212805</td>
#       <td id="T_f96e1_row4_col1" class="data row4 col1" >2.210187</td>
#       <td id="T_f96e1_row4_col2" class="data row4 col2" >0.448831</td>
#       <td id="T_f96e1_row4_col3" class="data row4 col3" >0.403888</td>
#       <td id="T_f96e1_row4_col4" class="data row4 col4" >1.375825</td>
#       <td id="T_f96e1_row4_col5" class="data row4 col5" >-0.643548</td>
#     </tr>
#     <tr>
#       <th id="T_f96e1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f96e1_row5_col0" class="data row5 col0" >-0.218494</td>
#       <td id="T_f96e1_row5_col1" class="data row5 col1" >-1.161965</td>
#       <td id="T_f96e1_row5_col2" class="data row5 col2" >0.484571</td>
#       <td id="T_f96e1_row5_col3" class="data row5 col3" >1.000136</td>
#       <td id="T_f96e1_row5_col4" class="data row5 col4" >0.627714</td>
#       <td id="T_f96e1_row5_col5" class="data row5 col5" >0.083205</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.style.background_gradient(cmap='magma')
# Out:
# <style type="text/css">
# #T_0d924_row0_col0 {
#   background-color: #942c80;
#   color: #f1f1f1;
# }
# #T_0d924_row0_col1 {
#   background-color: #b0357b;
#   color: #f1f1f1;
# }
# #T_0d924_row0_col2, #T_0d924_row1_col3, #T_0d924_row1_col5, #T_0d924_row2_col0, #T_0d924_row3_col4, #T_0d924_row5_col1 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_0d924_row0_col3 {
#   background-color: #992d80;
#   color: #f1f1f1;
# }
# #T_0d924_row0_col4 {
#   background-color: #fdebac;
#   color: #000000;
# }
# #T_0d924_row0_col5 {
#   background-color: #fed597;
#   color: #000000;
# }
# #T_0d924_row1_col0 {
#   background-color: #130d34;
#   color: #f1f1f1;
# }
# #T_0d924_row1_col1 {
#   background-color: #020109;
#   color: #f1f1f1;
# }
# #T_0d924_row1_col2, #T_0d924_row2_col4, #T_0d924_row3_col5, #T_0d924_row4_col0, #T_0d924_row4_col1, #T_0d924_row5_col3 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_0d924_row1_col4 {
#   background-color: #6e1e81;
#   color: #f1f1f1;
# }
# #T_0d924_row2_col1 {
#   background-color: #db476a;
#   color: #f1f1f1;
# }
# #T_0d924_row2_col2 {
#   background-color: #241253;
#   color: #f1f1f1;
# }
# #T_0d924_row2_col3 {
#   background-color: #f66e5c;
#   color: #f1f1f1;
# }
# #T_0d924_row2_col5 {
#   background-color: #752181;
#   color: #f1f1f1;
# }
# #T_0d924_row3_col0 {
#   background-color: #ca3e72;
#   color: #f1f1f1;
# }
# #T_0d924_row3_col1 {
#   background-color: #02020b;
#   color: #f1f1f1;
# }
# #T_0d924_row3_col2 {
#   background-color: #4e117b;
#   color: #f1f1f1;
# }
# #T_0d924_row3_col3 {
#   background-color: #fea36f;
#   color: #000000;
# }
# #T_0d924_row4_col2 {
#   background-color: #d9466b;
#   color: #f1f1f1;
# }
# #T_0d924_row4_col3 {
#   background-color: #f97b5d;
#   color: #f1f1f1;
# }
# #T_0d924_row4_col4 {
#   background-color: #febd82;
#   color: #000000;
# }
# #T_0d924_row4_col5, #T_0d924_row5_col4 {
#   background-color: #962c80;
#   color: #f1f1f1;
# }
# #T_0d924_row5_col0 {
#   background-color: #802582;
#   color: #f1f1f1;
# }
# #T_0d924_row5_col2 {
#   background-color: #e34e65;
#   color: #f1f1f1;
# }
# #T_0d924_row5_col5 {
#   background-color: #f1605d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0d924_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d924_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d924_row0_col0" class="data row0 col0" >-0.183639</td>
#       <td id="T_0d924_row0_col1" class="data row0 col1" >0.474137</td>
#       <td id="T_0d924_row0_col2" class="data row0 col2" >-0.329255</td>
#       <td id="T_0d924_row0_col3" class="data row0 col3" >-0.221098</td>
#       <td id="T_0d924_row0_col4" class="data row0 col4" >1.544897</td>
#       <td id="T_0d924_row0_col5" class="data row0 col5" >0.818156</td>
#     </tr>
#     <tr>
#       <th id="T_0d924_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d924_row1_col0" class="data row1 col0" >-0.407643</td>
#       <td id="T_0d924_row1_col1" class="data row1 col1" >-1.097898</td>
#       <td id="T_0d924_row1_col2" class="data row1 col2" >0.991999</td>
#       <td id="T_0d924_row1_col3" class="data row1 col3" >-1.151307</td>
#       <td id="T_0d924_row1_col4" class="data row1 col4" >0.459036</td>
#       <td id="T_0d924_row1_col5" class="data row1 col5" >-1.911524</td>
#     </tr>
#     <tr>
#       <th id="T_0d924_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0d924_row2_col0" class="data row2 col0" >-0.472914</td>
#       <td id="T_0d924_row2_col1" class="data row2 col1" >0.840233</td>
#       <td id="T_0d924_row2_col2" class="data row2 col2" >-0.133451</td>
#       <td id="T_0d924_row2_col3" class="data row2 col3" >0.350722</td>
#       <td id="T_0d924_row2_col4" class="data row2 col4" >1.618007</td>
#       <td id="T_0d924_row2_col5" class="data row2 col5" >-0.882411</td>
#     </tr>
#     <tr>
#       <th id="T_0d924_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0d924_row3_col0" class="data row3 col0" >-0.095701</td>
#       <td id="T_0d924_row3_col1" class="data row3 col1" >-1.092493</td>
#       <td id="T_0d924_row3_col2" class="data row3 col2" >-0.008957</td>
#       <td id="T_0d924_row3_col3" class="data row3 col3" >0.585711</td>
#       <td id="T_0d924_row3_col4" class="data row3 col4" >-0.104442</td>
#       <td id="T_0d924_row3_col5" class="data row3 col5" >1.083658</td>
#     </tr>
#     <tr>
#       <th id="T_0d924_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0d924_row4_col0" class="data row4 col0" >0.212805</td>
#       <td id="T_0d924_row4_col1" class="data row4 col1" >2.210187</td>
#       <td id="T_0d924_row4_col2" class="data row4 col2" >0.448831</td>
#       <td id="T_0d924_row4_col3" class="data row4 col3" >0.403888</td>
#       <td id="T_0d924_row4_col4" class="data row4 col4" >1.375825</td>
#       <td id="T_0d924_row4_col5" class="data row4 col5" >-0.643548</td>
#     </tr>
#     <tr>
#       <th id="T_0d924_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0d924_row5_col0" class="data row5 col0" >-0.218494</td>
#       <td id="T_0d924_row5_col1" class="data row5 col1" >-1.161965</td>
#       <td id="T_0d924_row5_col2" class="data row5 col2" >0.484571</td>
#       <td id="T_0d924_row5_col3" class="data row5 col3" >1.000136</td>
#       <td id="T_0d924_row5_col4" class="data row5 col4" >0.627714</td>
#       <td id="T_0d924_row5_col5" class="data row5 col5" >0.083205</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.abs().style.bar(align='left', width=90)
# Out:
# <style type="text/css">
# #T_a6f45_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 21.0%, transparent 21.0%);
# }
# #T_a6f45_row0_col1, #T_a6f45_row0_col3, #T_a6f45_row3_col0, #T_a6f45_row3_col2, #T_a6f45_row3_col4, #T_a6f45_row5_col5 {
#   width: 10em;
#   height: 80%;
# }
# #T_a6f45_row0_col2, #T_a6f45_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.3%, transparent 29.3%);
# }
# #T_a6f45_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 85.7%, transparent 85.7%);
# }
# #T_a6f45_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 36.2%, transparent 36.2%);
# }
# #T_a6f45_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 74.4%, transparent 74.4%);
# }
# #T_a6f45_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 32.3%, transparent 32.3%);
# }
# #T_a6f45_row1_col2, #T_a6f45_row1_col3, #T_a6f45_row1_col5, #T_a6f45_row2_col0, #T_a6f45_row2_col4, #T_a6f45_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 90.0%, transparent 90.0%);
# }
# #T_a6f45_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 21.1%, transparent 21.1%);
# }
# #T_a6f45_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 19.0%, transparent 19.0%);
# }
# #T_a6f45_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 11.4%, transparent 11.4%);
# }
# #T_a6f45_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 12.5%, transparent 12.5%);
# }
# #T_a6f45_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 39.3%, transparent 39.3%);
# }
# #T_a6f45_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 32.1%, transparent 32.1%);
# }
# #T_a6f45_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 35.3%, transparent 35.3%);
# }
# #T_a6f45_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 49.2%, transparent 49.2%);
# }
# #T_a6f45_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 27.9%, transparent 27.9%);
# }
# #T_a6f45_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 40.3%, transparent 40.3%);
# }
# #T_a6f45_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 17.7%, transparent 17.7%);
# }
# #T_a6f45_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 75.6%, transparent 75.6%);
# }
# #T_a6f45_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 27.6%, transparent 27.6%);
# }
# #T_a6f45_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 35.7%, transparent 35.7%);
# }
# #T_a6f45_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 43.5%, transparent 43.5%);
# }
# #T_a6f45_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 75.4%, transparent 75.4%);
# }
# #T_a6f45_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 31.1%, transparent 31.1%);
# }
# </style>
# <table id="T_a6f45_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6f45_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6f45_row0_col0" class="data row0 col0" >0.183639</td>
#       <td id="T_a6f45_row0_col1" class="data row0 col1" >0.474137</td>
#       <td id="T_a6f45_row0_col2" class="data row0 col2" >0.329255</td>
#       <td id="T_a6f45_row0_col3" class="data row0 col3" >0.221098</td>
#       <td id="T_a6f45_row0_col4" class="data row0 col4" >1.544897</td>
#       <td id="T_a6f45_row0_col5" class="data row0 col5" >0.818156</td>
#     </tr>
#     <tr>
#       <th id="T_a6f45_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6f45_row1_col0" class="data row1 col0" >0.407643</td>
#       <td id="T_a6f45_row1_col1" class="data row1 col1" >1.097898</td>
#       <td id="T_a6f45_row1_col2" class="data row1 col2" >0.991999</td>
#       <td id="T_a6f45_row1_col3" class="data row1 col3" >1.151307</td>
#       <td id="T_a6f45_row1_col4" class="data row1 col4" >0.459036</td>
#       <td id="T_a6f45_row1_col5" class="data row1 col5" >1.911524</td>
#     </tr>
#     <tr>
#       <th id="T_a6f45_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6f45_row2_col0" class="data row2 col0" >0.472914</td>
#       <td id="T_a6f45_row2_col1" class="data row2 col1" >0.840233</td>
#       <td id="T_a6f45_row2_col2" class="data row2 col2" >0.133451</td>
#       <td id="T_a6f45_row2_col3" class="data row2 col3" >0.350722</td>
#       <td id="T_a6f45_row2_col4" class="data row2 col4" >1.618007</td>
#       <td id="T_a6f45_row2_col5" class="data row2 col5" >0.882411</td>
#     </tr>
#     <tr>
#       <th id="T_a6f45_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6f45_row3_col0" class="data row3 col0" >0.095701</td>
#       <td id="T_a6f45_row3_col1" class="data row3 col1" >1.092493</td>
#       <td id="T_a6f45_row3_col2" class="data row3 col2" >0.008957</td>
#       <td id="T_a6f45_row3_col3" class="data row3 col3" >0.585711</td>
#       <td id="T_a6f45_row3_col4" class="data row3 col4" >0.104442</td>
#       <td id="T_a6f45_row3_col5" class="data row3 col5" >1.083658</td>
#     </tr>
#     <tr>
#       <th id="T_a6f45_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6f45_row4_col0" class="data row4 col0" >0.212805</td>
#       <td id="T_a6f45_row4_col1" class="data row4 col1" >2.210187</td>
#       <td id="T_a6f45_row4_col2" class="data row4 col2" >0.448831</td>
#       <td id="T_a6f45_row4_col3" class="data row4 col3" >0.403888</td>
#       <td id="T_a6f45_row4_col4" class="data row4 col4" >1.375825</td>
#       <td id="T_a6f45_row4_col5" class="data row4 col5" >0.643548</td>
#     </tr>
#     <tr>
#       <th id="T_a6f45_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a6f45_row5_col0" class="data row5 col0" >0.218494</td>
#       <td id="T_a6f45_row5_col1" class="data row5 col1" >1.161965</td>
#       <td id="T_a6f45_row5_col2" class="data row5 col2" >0.484571</td>
#       <td id="T_a6f45_row5_col3" class="data row5 col3" >1.000136</td>
#       <td id="T_a6f45_row5_col4" class="data row5 col4" >0.627714</td>
#       <td id="T_a6f45_row5_col5" class="data row5 col5" >0.083205</td>
#     </tr>
#   </tbody>
# </table>

# %%
head = {'selector': 'th', 'props': [('text-align', 'center')]}
df.style.set_table_styles([head]).bar(align='mid', color=['red', 'green'], vmin=-3, vmax=3)
# Out:
# <style type="text/css">
# #T_da9e8_ th {
#   text-align: center;
# }
# #T_da9e8_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 46.9%, red 46.9%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 57.9%, transparent 57.9%);
# }
# #T_da9e8_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 44.5%, red 44.5%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 46.3%, red 46.3%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 75.7%, transparent 75.7%);
# }
# #T_da9e8_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 63.6%, transparent 63.6%);
# }
# #T_da9e8_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 43.2%, red 43.2%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 31.7%, red 31.7%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 66.5%, transparent 66.5%);
# }
# #T_da9e8_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 30.8%, red 30.8%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 57.7%, transparent 57.7%);
# }
# #T_da9e8_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 18.1%, red 18.1%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 42.1%, red 42.1%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 64.0%, transparent 64.0%);
# }
# #T_da9e8_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 47.8%, red 47.8%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 55.8%, transparent 55.8%);
# }
# #T_da9e8_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 77.0%, transparent 77.0%);
# }
# #T_da9e8_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 35.3%, red 35.3%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 48.4%, red 48.4%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 31.8%, red 31.8%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 49.9%, red 49.9%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 59.8%, transparent 59.8%);
# }
# #T_da9e8_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 48.3%, red 48.3%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 68.1%, transparent 68.1%);
# }
# #T_da9e8_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 53.5%, transparent 53.5%);
# }
# #T_da9e8_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 86.8%, transparent 86.8%);
# }
# #T_da9e8_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 57.5%, transparent 57.5%);
# }
# #T_da9e8_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 56.7%, transparent 56.7%);
# }
# #T_da9e8_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 72.9%, transparent 72.9%);
# }
# #T_da9e8_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 39.3%, red 39.3%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 46.4%, red 46.4%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 30.6%, red 30.6%, red 50.0%, transparent 50.0%);
# }
# #T_da9e8_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 58.1%, transparent 58.1%);
# }
# #T_da9e8_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 66.7%, transparent 66.7%);
# }
# #T_da9e8_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 60.5%, transparent 60.5%);
# }
# #T_da9e8_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 51.4%, transparent 51.4%);
# }
# </style>
# <table id="T_da9e8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da9e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da9e8_row0_col0" class="data row0 col0" >-0.183639</td>
#       <td id="T_da9e8_row0_col1" class="data row0 col1" >0.474137</td>
#       <td id="T_da9e8_row0_col2" class="data row0 col2" >-0.329255</td>
#       <td id="T_da9e8_row0_col3" class="data row0 col3" >-0.221098</td>
#       <td id="T_da9e8_row0_col4" class="data row0 col4" >1.544897</td>
#       <td id="T_da9e8_row0_col5" class="data row0 col5" >0.818156</td>
#     </tr>
#     <tr>
#       <th id="T_da9e8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_da9e8_row1_col0" class="data row1 col0" >-0.407643</td>
#       <td id="T_da9e8_row1_col1" class="data row1 col1" >-1.097898</td>
#       <td id="T_da9e8_row1_col2" class="data row1 col2" >0.991999</td>
#       <td id="T_da9e8_row1_col3" class="data row1 col3" >-1.151307</td>
#       <td id="T_da9e8_row1_col4" class="data row1 col4" >0.459036</td>
#       <td id="T_da9e8_row1_col5" class="data row1 col5" >-1.911524</td>
#     </tr>
#     <tr>
#       <th id="T_da9e8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_da9e8_row2_col0" class="data row2 col0" >-0.472914</td>
#       <td id="T_da9e8_row2_col1" class="data row2 col1" >0.840233</td>
#       <td id="T_da9e8_row2_col2" class="data row2 col2" >-0.133451</td>
#       <td id="T_da9e8_row2_col3" class="data row2 col3" >0.350722</td>
#       <td id="T_da9e8_row2_col4" class="data row2 col4" >1.618007</td>
#       <td id="T_da9e8_row2_col5" class="data row2 col5" >-0.882411</td>
#     </tr>
#     <tr>
#       <th id="T_da9e8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_da9e8_row3_col0" class="data row3 col0" >-0.095701</td>
#       <td id="T_da9e8_row3_col1" class="data row3 col1" >-1.092493</td>
#       <td id="T_da9e8_row3_col2" class="data row3 col2" >-0.008957</td>
#       <td id="T_da9e8_row3_col3" class="data row3 col3" >0.585711</td>
#       <td id="T_da9e8_row3_col4" class="data row3 col4" >-0

# %%
df.style.bar(align='mid', width=50).apply(gold_max, axis=None).applymap(neg_red)
# Out:
# <style type="text/css">
# #T_5bb7d_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 21.1%, #d65f5f 21.1%, #d65f5f 34.5%, transparent 34.5%);
#   color: red;
# }
# #T_5bb7d_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 17.2%, #d65f5f 17.2%, #d65f5f 24.3%, transparent 24.3%);
#   color: white;
# }
# #T_5bb7d_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 12.5%, transparent 12.5%);
#   color: red;
# }
# #T_5bb7d_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 21.6%, #d65f5f 21.6%, #d65f5f 26.8%, transparent 26.8%);
#   color: red;
# }
# #T_5bb7d_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 3.0%, #d65f5f 3.0%, #d65f5f 47.9%, transparent 47.9%);
#   color: white;
# }
# #T_5bb7d_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 31.9%, #d65f5f 31.9%, #d65f5f 45.6%, transparent 45.6%);
#   color: white;
# }
# #T_5bb7d_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 4.8%, #d65f5f 4.8%, #d65f5f 34.5%, transparent 34.5%);
#   color: red;
# }
# #T_5bb7d_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.9%, #d65f5f 0.9%, #d65f5f 17.2%, transparent 17.2%);
#   color: red;
# }
# #T_5bb7d_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 12.5%, #d65f5f 12.5%, #d65f5f 50.0%, transparent 50.0%);
#   color: white;
# }
# #T_5bb7d_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 26.8%, transparent 26.8%);
#   color: red;
# }
# #T_5bb7d_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 3.0%, #d65f5f 3.0%, #d65f5f 16.4%, transparent 16.4%);
#   color: white;
# }
# #T_5bb7d_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 31.9%, transparent 31.9%);
#   color: red;
# }
# #T_5bb7d_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 34.5%, transparent 34.5%);
#   color: red;
# }
# #T_5bb7d_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 17.2%, #d65f5f 17.2%, #d65f5f 29.7%, transparent 29.7%);
#   color: white;
# }
# #T_5bb7d_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.4%, #d65f5f 7.4%, #d65f5f 12.5%, transparent 12.5%);
#   color: red;
# }
# #T_5bb7d_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 26.8%, #d65f5f 26.8%, #d65f5f 34.9%, transparent 34.9%);
#   color: white;
# }
# #T_5bb7d_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 3.0%, #d65f5f 3.0%, #d65f5f 50.0%, transparent 50.0%);
#   color: white;
# }
# #T_5bb7d_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 17.2%, #d65f5f 17.2%, #d65f5f 31.9%, transparent 31.9%);
#   color: red;
# }
# #T_5bb7d_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 27.5%, #d65f5f 27.5%, #d65f5f 34.5%, transparent 34.5%);
#   color: red;
# }
# #T_5bb7d_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 1.0%, #d65f5f 1.0%, #d65f5f 17.2%, transparent 17.2%);
#   color: red;
# }
# #T_5bb7d_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 12.1%, #d65f5f 12.1%, #d65f5f 12.5%, transparent 12.5%);
#   color: red;
# }
# #T_5bb7d_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 26.8%, #d65f5f 26.8%, #d65f5f 40.4%, transparent 40.4%);
#   color: white;
# }
# #T_5bb7d_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 3.0%, transparent 3.0%);
#   color: red;
# }
# #T_5bb7d_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 31.9%, #d65f5f 31.9%, #d65f5f 50.0%, transparent 50.0%);
#   color: white;
# }
# #T_5bb7d_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 34.5%, #d65f5f 34.5%, #d65f5f 50.0%, transparent 50.0%);
#   color: white;
# }
# #T_5bb7d_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 17.2%, #d65f5f 17.2%, #d65f5f 50.0%, transparent 50.0%);
#   background-color: #c78f2e;
#   color: white;
# }
# #T_5bb7d_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 12.5%, #d65f5f 12.5%, #d65f5f 29.4%, transparent 29.4%);
#   color: white;
# }
# #T_5bb7d_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 26.8%, #d65f5f 26.8%, #d65f5f 36.1%, transparent 36.1%);
#   color: white;
# }
# #T_5bb7d_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 3.0%, #d65f5f 3.0%, #d65f5f 43.0%, transparent 43.0%);
#   color: white;
# }
# #T_5bb7d_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 21.2%, #d65f5f 21.2%, #d65f5f 31.9%, transparent 31.9%);
#   color: red;
# }
# #T_5bb7d_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 18.6%, #d65f5f 18.6%, #d65f5f 34.5%, transparent 34.5%);
#   color: red;
# }
# #T_5bb7d_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 17.2%, transparent 17.2%);
#   color: red;
# }
# #T_5bb7d_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 12.5%, #d65f5f 12.5%, #d65f5f 30.8%, transparent 30.8%);
#   color: white;
# }
# #T_5bb7d_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 26.8%, #d65f5f 26.8%, #d65f5f 50.0%, transparent 50.0%);
#   color: white;
# }
# #T_5bb7d_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 3.0%, #d65f5f 3.0%, #d65f5f 21.3%, transparent 21.3%);
#   color: white;
# }
# #T_5bb7d_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 31.9%, #d65f5f 31.9%, #d65f5f 33.3%, transparent 33.3%);
#   color: white;
# }
# </style>
# <table id="T_5bb7d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5bb7d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5bb7d_row0_col0" class="data row0 col0" >-0.183639</td>
#       <td id="T_5bb7d_row0_col1" class="data row0 col1" >0.474137</td>
#       <td id="T_5bb7d_row0_col2" class="data row0 col2" >-0.329255</td>
#       <td id="T_5bb7d_row0_col3" class="data row0 col3" >-0.221098</td>
#       <td id="T_5bb7d_row0_col4" class="data row0 col4" >1.544897</td>
#       <td id="T_5bb7d_row0_col5" class="data row0 col5" >0.818156</td>
#     </tr>
#     <tr>
#       <th id="T_5bb7d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5bb7d_row1_col0" class="data row1 col0" >-0.407643</td>
#       <td id="T_5bb7d_row1_col1" class="data row1 col1" >-1.097898</td>
#       <td id="T_5bb7d_row1_col2" class="data row1 col2" >0.991999</td>
#       <td id="T_5bb7d_row1_col3" class="data row1 col3" >-1.151307</td>
#       <td id="T_5bb7d_row1_col4" class="data row1 col4" >0.459036</td>
#       <td id="T_5bb7d_row1_col5" class="data row1 col5" >-1.911524</td>
#     </tr>
#     <tr>
#       <th id="T_5bb7d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5bb7d_row2_col0" class="data row2 col0" >-0.472914</td>
#       <td id="T_5bb7d_row2_col1" class="data row2 col1" >0.840233</td>
#       <td id="T_5bb7d_row2_col2" class="data row2 col2" >-0.133451</td>
#       <td id="T_5bb7d_row2_col3" class="data row2 col3" >0.350722</td>
#       <td id="T_5bb7d_row2_col4" class="data row2 col4" >1.618007</td
